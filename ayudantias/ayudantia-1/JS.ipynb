# %% [markdown]
# # Introducción a JavaScript

# %% [markdown]
# ## ¿Qué es JavaScript?
#
# JavaScript es un lenguaje de programación que se utiliza principalmente para crear páginas web interactivas. Una página web interactiva es una página web que permite a los usuarios interactuar con ella. Por ejemplo, los usuarios pueden hacer clic en un botón, introducir texto en un cuadro de texto o mover el ratón. Cuando un usuario interactúa con una página web, JavaScript se utiliza para procesar la información que el usuario introduce y para actualizar la página web en consecuencia.
#
#
# ## DOM, elementos y nodos
#
# El **Document Object Model** (DOM) es una representación de la estructura de una página web. El DOM es una estructura de árbol que consta de nodos. Cada nodo representa un elemento en la página web, como un párrafo, un encabezado o un botón. Los nodos pueden tener hijos, que son otros nodos que están contenidos dentro de ellos. Por ejemplo, un nodo de párrafo puede tener un nodo de texto como hijo. Los nodos también pueden tener hermanos, que son otros nodos que tienen el mismo padre. Por ejemplo, dos nodos de párrafo que tienen el mismo padre son hermanos.
#
# En resumidas cuentas, el DOM:
#
# **Corresponde a una representación jerárquica estructurada en forma de árbol de un documento HTML.**
#
# En resumen, es un esquema visual de como se organiza un HTML.
#
# Ejemplo:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Ayudantia 1</title>
# </head>
# <body>
#     <h1>DOM? Se come?/h1>
#     <p>NO lo se :(</p>
#     <table>
#         <tr>
#             <td>Hola</td>
#             <td>Mundo</td>
#         </tr>
#     </table>
# </body>
# </html>
# ```
#
# En este caso, el DOM se vería de la siguiente manera:
#
# ![Diagrama DOM](attachment:image.png)
#
#
# ## Nodos VS Elementos
#
# **Nodo:**
# Un nodo es cualquier objeto del
# DOM, pudiendo ser el documento
# mismo (document), tag HTML,
# texto e incluso los comentarios
#
# Existen tipos de nodos:
#
# ‘Text node’
# ‘Comment node’
# ‘Attribute Node’
# ‘Document Node’
# ‘Element Node’
#
#
# Dentor dfe los nodos existen los mismos elementos.
#
# **Elemento:**
# Un elemento en el DOM es
# específicamente una etiqueta
# HTML.
# Tienen propiedades, métodos,
# eventos y además, son
# manipulables
